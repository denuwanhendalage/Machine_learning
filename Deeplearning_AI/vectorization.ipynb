# %% [markdown]
# ### Vectorization Demo

# %%
import numpy as np
a=np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
import time

a=np.random.rand(1000000)
b=np.random.rand(1000000)

tic=time.time()
c=np.dot(a,b)
toc=time.time()

print(c)
print("Vectorized version: "+str(1000*(toc-tic))+"ms")


c=0
tic=time.time()
for i in range(1000000):
    c+=a[i]*b[i]

toc=time.time()

print(c)
print("For loop: "+str(1000*(toc-tic))+"ms")
# Out:
# 249952.06438627074
# Vectorized version: 1.184225082397461ms
# 249952.0643862697
# For loop: 436.81979179382324ms

# %% [markdown]
# ### Broadcasting examples

# %%
import numpy as np

A=np.array([[56.0,0.0,4.4,68.0],[1.2,104.0,52.0,8.0],[1.8,135.0,99.0,0.9]])
print(A)
# Out:
# [[ 56.    0.    4.4  68. ]
#  [  1.2 104.   52.    8. ]
#  [  1.8 135.   99.    0.9]]

# %%
cal=A.sum(axis=0)
print(cal)
# Out:
# [ 59.  239.  155.4  76.9]

# %%
percentage=100*A/cal.reshape(1,4)
print(percentage)
# Out:
# [[94.91525424  0.          2.83140283 88.42652796]
#  [ 2.03389831 43.51464435 33.46203346 10.40312094]
#  [ 3.05084746 56.48535565 63.70656371  1.17035111]]

# %% [markdown]
# ### Python numpy vectors

# %%
import numpy as np


a=np.random.randn(5)
print(a)
# Out:
# [ 1.07774232 -0.39654043 -0.47993156  0.16694399  0.3500445 ]

# %%
print(a.shape)
# Out:
# (5,)

# %%
print(a.T)
# Out:
# [ 1.07774232 -0.39654043 -0.47993156  0.16694399  0.3500445 ]

# %%
print(np.dot(a,a.T))
# Out:
# 1.6995085585584102

# %%
a=np.random.randn(5,1)
print(a)
# Out:
# [[0.70770392]
#  [1.26515964]
#  [0.08722922]
#  [0.86310485]
#  [0.35248726]]

# %%
print(a.T)
# Out:
# [[0.70770392 1.26515964 0.08722922 0.86310485 0.35248726]]

# %%
print(np.dot(a,a.T))
# Out:
# [[0.50084483 0.89535843 0.06173246 0.61082268 0.24945661]
#  [0.89535843 1.60062892 0.11035888 1.09196543 0.44595265]
#  [0.06173246 0.11035888 0.00760894 0.07528796 0.03074719]
#  [0.61082268 1.09196543 0.07528796 0.74494999 0.30423346]
#  [0.24945661 0.44595265 0.03074719 0.30423346 0.12424727]]

# %% [markdown]
# ![image.png](attachment:image.png)
